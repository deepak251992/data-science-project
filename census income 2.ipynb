# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("census_income.csv")
data
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
data.shape
# Out:
# (32560, 15)

# %%
data.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %%
data.nunique()
# Out:
# Age                  73
# Workclass             9
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        119
# Capital_loss         92
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
data.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32560.0      38.581634      13.640642     17.0      28.0
# Fnlwgt          32560.0  189781.814373  105549.764924  12285.0  117831.5
# Education_num   32560.0      10.080590       2.572709      1.0       9.0
# Capital_gain    32560.0    1077.615172    7385.402999      0.0       0.0
# Capital_loss    32560.0      87.306511     402.966116      0.0       0.0
# Hours_per_week  32560.0      40.437469      12.347618      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178363.0  237054.5  1484705.0
# Education_num       10.0      12.0       16.0
# Capital_gain         0.0       0.0    99999.0
# Capital_loss         0.0       0.0     4356.0
# Hours_per_week      40.0      45.0       99.0

# %% [markdown]
# ### Value count function

# %%
data['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
data['Occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
data['Native_country'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  France                           29
#  Greece                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Cambodia                         19
#  Trinadad&Tobago                  19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Honduras                         13
#  Hungary                          13
#  Scotland                         12
#  Holand-Netherlands                1
# Name: Native_country, dtype: int64

# %%
data['Marital_status'].value_counts()
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
data['Sex'].value_counts()
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
data['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
data['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
sns.countplot(data['Income'],palette='coolwarm',hue='Sex',data=data)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(data['Income'],palette='coolwarm',hue='Race',data=data)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
sns.countplot(data['Income'],palette='coolwarm',hue='Relationship',data=data)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %%
## filling ? values
data['Workclass']=data['Workclass'].replace('?','Private')
data['Occupation']=data['Occupation'].replace('?','Prof-specialty')
data['Native_country']=data['Native_country'].replace('?','United-States')

# %%
data.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %% [markdown]
# ## feature engineering

# %%
## filling ? values
data['Workclass'] = np.where(data['Workclass'] == ' ?', np.nan, data['Workclass'])
data['Occupation'] = np.where(data['Occupation'] == ' ?', np.nan, data['Occupation'])
data['Native_country'] = np.where(data['Native_country'] == ' ?', np.nan, data['Native_country'])

# %%
data
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
data.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043159      0.000437     -0.010259
# Education_num   0.036527 -0.043159       1.000000      0.122627      0.079932
# Capital_gain    0.077674  0.000437       0.122627      1.000000     -0.031614
# Capital_loss    0.057775 -0.010259       0.079932     -0.031614      1.000000
# Hours_per_week  0.068756 -0.018770       0.148127      0.078409      0.054256
#
#                 Hours_per_week
# Age                   0.068756
# Fnlwgt               -0.018770
# Education_num         0.148127
# Capital_gain          0.078409
# Capital_loss          0.054256
# Hours_per_week        1.000000

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # histogram

# %%
data.hist(figsize=(12,12),layout=(3,4),sharex=False)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Fnlwgt'}>,
#         <AxesSubplot:title={'center':'Education_num'}>,
#         <AxesSubplot:title={'center':'Capital_gain'}>],
#        [<AxesSubplot:title={'center':'Capital_loss'}>,
#         <AxesSubplot:title={'center':'Hours_per_week'}>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # boxplot

# %%
data.plot(kind='box',figsize=(20,20),layout=(4,3),sharex=False,subplots=True)
# Out:
# Age                   AxesSubplot(0.125,0.71587;0.227941x0.16413)
# Fnlwgt             AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# Education_num      AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# Capital_gain         AxesSubplot(0.125,0.518913;0.227941x0.16413)
# Capital_loss      AxesSubplot(0.398529,0.518913;0.227941x0.16413)
# Hours_per_week    AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# dtype: object

# %% [markdown]
# # feature scalling

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder

# %%
data=data.apply(LabelEncoder().fit_transform)
data.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   33          5    2925          9             12               2
# 1   21          3   14085         11              8               0
# 2   36          3   15335          1              6               2
# 3   11          3   19354          9             12               2
# 4   20          3   17699         12             13               2
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           3             0     4    1             0             0
# 1           5             1     4    1             0             0
# 2           5             0     2    1             0             0
# 3           9             5     2    0             0             0
# 4           3             5     4    0             0             0
#
#    Hours_per_week  Native_country  Income
# 0              12              38       0
# 1              39              38       0
# 2              39              38       0
# 3              39               4       0
# 4              39              38       0

# %%
x = data.drop(['Income'], axis=1)
y = data['Income']

# %%
from sklearn.ensemble import ExtraTreesClassifier
selector = ExtraTreesClassifier(random_state=42)
fit = selector.fit(x,y)
feature_imp = selector.feature_importances_
feature_imp
# Out:
# array([0.15052675, 0.04447418, 0.15821502, 0.03634333, 0.08340948,
#        0.06968428, 0.07413275, 0.08842755, 0.01477874, 0.02721793,
#        0.10735579, 0.03334839, 0.09237796, 0.01970785])

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 32560, dtype: int32

# %%
x = x.drop(['Workclass', 'Education', 'Race', 'Sex',
            'Capital_loss', 'Native_country', 'Capital_gain'], axis=1)

x
# Out:
#        Age  Fnlwgt  Education_num  Marital_status  Occupation  Relationship  \
# 0       33    2925             12               2           3             0
# 1       21   14085              8               0           5             1
# 2       36   15335              6               2           5             0
# 3       11   19354             12               2           9             5
# 4       20   17699             13               2           3             5
# ...    ...     ...            ...             ...         ...           ...
# 32555   10   16527             11               2          12             5
# 32556   23    8079              8               2           6             0
# 32557   41    7882              8               6           0             4
# 32558    5   12880              8               4           0             3
# 32559   35   17824              8               2           3             5
#
#        Hours_per_week
# 0                  12
# 1                  39
# 2                  39
# 3                  39
# 4                  39
# ...               ...
# 32555              37
# 32556              39
# 32557              39
# 32558              19
# 32559              39
#
# [32560 rows x 7 columns]

# %% [markdown]
# ##### remove skewness and outliers

# %%
x.skew().sort_values(ascending = False)
# Out:
# Relationship      0.786784
# Age               0.555583
# Occupation        0.126702
# Hours_per_week    0.069753
# Fnlwgt            0.063137
# Marital_status   -0.013448
# Education_num    -0.311630
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
X_new = power_transform(x)

# %%
pd.DataFrame(X_new, columns = x.columns).skew().sort_values(ascending = False)
# Out:
# Hours_per_week    0.199586
# Relationship      0.122917
# Education_num     0.019545
# Age              -0.104049
# Marital_status   -0.114201
# Occupation       -0.203407
# Fnlwgt           -0.263791
# dtype: float64

# %%
X = pd.DataFrame(X_new, columns = x.columns)

# %%
X.plot(kind='box',figsize=(20,20),layout=(4,3),sharex=False,subplots=True)
# Out:
# Age                   AxesSubplot(0.125,0.71587;0.227941x0.16413)
# Fnlwgt             AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# Education_num      AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# Marital_status       AxesSubplot(0.125,0.518913;0.227941x0.16413)
# Occupation        AxesSubplot(0.398529,0.518913;0.227941x0.16413)
# Relationship      AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# Hours_per_week       AxesSubplot(0.125,0.321957;0.227941x0.16413)
# dtype: object

# %%
X.head()
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Income, dtype: int32

# %%
from scipy.stats import zscore

print('High Side Outliers present')
print((zscore(X)<3).all())

print('****************************************')

print('Low Side Outliers Present')
print((zscore(X)>-3).all())
# Out:
# High Side Outliers present
# Age                True
# Fnlwgt             True
# Education_num      True
# Marital_status     True
# Occupation         True
# Relationship       True
# Hours_per_week    False
# dtype: bool
# ****************************************
# Low Side Outliers Present
# Age                True
# Fnlwgt             True
# Education_num      True
# Marital_status     True
# Occupation         True
# Relationship       True
# Hours_per_week    False
# dtype: bool

# %%
 #Validating OUtliers

#1st Quantile
q1 = x.quantile(0.25)

#3rd quantile
q3 = x.quantile(0.75)

#IQR
iqr = q3 - q1

# %%
Hours_per_week_high = q3.Hours_per_week + (1.5 * iqr.Hours_per_week)

# Check the Indexes which have higher values

index1 = np.where(X['Hours_per_week']> Hours_per_week_high)

X = X.drop(X['Hours_per_week'].index[index1])

y = y.drop(y.index[index1])

print(X.shape)
print(y.shape)
# Out:
# (32560, 7)
# (32560,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()

vif['vif'] = [variance_inflation_factor(x_scaled, i) for i in range (x_scaled.shape[1])]

vif['features'] = x.columns


# Lets check the values 
vif
# Out:
#         vif        features
# 0  1.142760             Age
# 1  1.008352          Fnlwgt
# 2  1.032349   Education_num
# 3  1.125132  Marital_status
# 4  1.010008      Occupation
# 5  1.154336    Relationship
# 6  1.116220  Hours_per_week

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, roc_auc_score, classification_report

# %%
x_scaled.shape
# Out:
# (32560, 7)

# %%
y.shape
# Out:
# (32560,)

# %% [markdown]
# ### model building

# %%
from sklearn.linear_model import LogisticRegression
maxAccu = 0
maxRS = 0

for i in range(1,5000):
    x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size = 0.25, random_state = i)
    reg = LogisticRegression()
    reg.fit(x_train, y_train)
    y_pred = reg.predict(x_test)
    acc = accuracy_score(y_test,y_pred)
    print('accuracy score', acc, 'random_state', i)
    
    if acc > maxAccu:
        maxAccu = acc
        maxRS = i
        print('accuracy score', maxAccu, 'random_state', i)
# Out:
# accuracy score 0.8057739557739557 random_state 1
# accuracy score 0.8057739557739557 random_state 1
# accuracy score 0.7981572481572482 random_state 2
# accuracy score 0.8002457002457003 random_state 3
# accuracy score 0.802948402948403 random_state 4
# accuracy score 0.8036855036855037 random_state 5
# accuracy score 0.7996314496314496 random_state 6
# accuracy score 0.8056511056511056 random_state 7
# accuracy score 0.8068796068796069 random_state 8
# accuracy score 0.8068796068796069 random_state 8
# accuracy score 0.8041769041769041 random_state 9
# accuracy score 0.8036855036855037 random_state 10
# accuracy score 0.8049140049140049 random_state 11
# accuracy score 0.8002457002457003 random_state 12
# accuracy score 0.8004914004914004 random_state 13
# accuracy score 0.8041769041769041 random_state 14
# accuracy score 0.8042997542997543 random_state 15
# accuracy score 0.803931203931204 random_state 16
# accuracy score 0.7958230958230958 random_state 17
# accuracy score 0.8041769041769041 random_state 18
# accuracy score 0.8034398034398035 random_state 19
# accuracy score 0.798034398034398 random_state 20
# accuracy score 0.8027027027027027 random_state 21
# accuracy score 0.8090909090909091 random_state 22
# accuracy score 0.8090909090909091 random_state 22
# accuracy score 0.8085995085995086 random_state 23
# accuracy score 0.8028255528255528 random_state 24
# accuracy score 0.8041769041769041 random_state 25
# accuracy score 0.8011056511056511 random_state 26
# accuracy score 0.807002457002457 random_state 27
# accuracy score 0.8049140049140049 random_state 28
# accuracy score 0.801965601965602 random_state 29
# accuracy score 0.8083538083538083 random_state 30
# accuracy score 0.806019656019656 random_state 31
# accuracy score 0.8097051597051597 random_state 32
# accuracy score 0.8097051597051597 random_state 32
# accuracy score 0.8013513513513514 random_state 33
# accuracy score 0.8018427518427519 random_state 34
# accuracy score 0.8012285012285012 random_state 35
# accuracy score 0.799017199017199 random_state 36
# accuracy score 0.8014742014742015 random_state 37
# accuracy score 0.8040540540540541 random_state 38
# accuracy score 0.8035626535626536 random_state 39
# accuracy score 0.8023341523341523 random_state 40
# accuracy score 0.8051597051597051 random_state 41
# accuracy score 0.7984029484029485 random_state 42
# accuracy score 0.8 random_state 4698
# accuracy score 0.803931203931204 random_state 4699
# accuracy score 0.8004914004914004 random_state 4700
# accuracy score 0.7995085995085995 random_state 4701
# accuracy score 0.8020884520884521 random_state 4702
# accuracy score 0.7931203931203932 random_state 4703
# accuracy score 0.8054054054054054 random_state 4704
# accuracy score 0.8041769041769041 random_state 4705
# accuracy score 0.8056511056511056 random_state 4706
# accuracy score 0.8006142506142506 random_state 4707
# accuracy score 0.8013513513513514 random_state 4708
# accuracy score 0.8022113022113022 random_state 4709
# accuracy score 0.8035626535626536 random_state 4710
# accuracy score 0.7985257985257985 random_state 4711
# accuracy score 0.7998771498771499 random_state 4712
# accuracy score 0.8042997542997543 random_state 4713
# accuracy score 0.8074938574938575 random_state 4714
# accuracy score 0.8050368550368551 random_state 4715
# accuracy score 0.8042997542997543 random_state 4716
# accuracy score 0.8011056511056511 random_state 4717
# accuracy score 0.8028255528255528 random_state 4718
# accuracy score 0.8105651105651106 random_state 4719
# accuracy score 0.7959459459459459 random_state 4720
# accuracy score 0.8012285012285012 random_state 4721
# accuracy score 0.8052825552825553 random_state 4722
# accuracy score 0.806019656019656 random_state 4723
# accuracy score 0.7981572481572482 random_state 4724
# accuracy score 0.7977886977886978 random_state 4725
# accuracy score 0.7985257985257985 random_state 4726
# accuracy score 0.8054054054054054 random_state 4727
# accuracy score 0.8077395577395577 random_state 4728
# accuracy score 0.8063882063882064 random_state 4729
# accuracy score 0.8006142506142506 random_state 4730
# accuracy score 0.8062653562653562 random_state 4731
# accuracy score 0.806019656019656 random_state 4732
# accuracy score 0.8031941031941032 random_state 4733
# accuracy score 0.8003685503685504 random_state 4734
# accuracy score 0.7945945945945946 random_state 4735
# accuracy score 0.8052825552825553 random_state 4736
# accuracy score 0.8088452088452088 random_state 4737
# accuracy score 0.7987714987714988 random_state 4738
# accuracy score 0.803931203931204 random_state 4739
# accuracy score 0.8012285012285012 random_state 4740
# accuracy score 0.7968058968058968 random_state 4741
# accuracy score 0.8028255528255528 random_state 4742
# accuracy score 0.8024570024570025 random_state 4743
# accuracy score 0.8022113022113022 random_state 4744
# accuracy score 0.8024570024570025 random_state 4745
# accuracy score 0.8071253071253072 random_state 4746
# accuracy score 0.8047911547911548 random_state 4747
# accuracy score 0.8041769041769041 random_state 4748
# accuracy score 0.803071253071253 random_state 4749
# accuracy score 0.8076167076167076 random_state 4750
# accuracy score 0.8062653562653562 random_state 4751
# accuracy score 0.8045454545454546 random_state 4752
# accuracy score 0.7981572481572482 random_state 4753
# accuracy score 0.8013513513513514 random_state 4754
# accuracy score 0.8084766584766585 random_state 4755
# accuracy score 0.7982800982800983 random_state 4756
# accuracy score 0.8018427518427519 random_state 4757
# accuracy score 0.8025798525798525 random_state 4758
# accuracy score 0.8012285012285012 random_state 4759
# accuracy score 0.8087223587223588 random_state 4760
# accuracy score 0.7974201474201474 random_state 4761
# accuracy score 0.8090909090909091 random_state 4762
# accuracy score 0.801965601965602 random_state 4763
# accuracy score 0.8061425061425062 random_state 4764
# accuracy score 0.8052825552825553 random_state 4765
# accuracy score 0.7953316953316953 random_state 4766
# accuracy score 0.8076167076167076 random_state 4767
# accuracy score 0.8045454545454546 random_state 4768
# accuracy score 0.803931203931204 random_state 4769
# accuracy score 0.8068796068796069 random_state 4770
# accuracy score 0.8024570024570025 random_state 4771
# accuracy score 0.8022113022113022 random_state 4772
# accuracy score 0.8017199017199017 random_state 4773
# accuracy score 0.801965601965602 random_state 4774
# accuracy score 0.8076167076167076 random_state 4775
# accuracy score 0.7986486486486486 random_state 4776
# accuracy score 0.8045454545454546 random_state 4777
# accuracy score 0.8056511056511056 random_state 4778
# accuracy score 0.8034398034398035 random_state 4779
# accuracy score 0.807985257985258 random_state 4780
# accuracy score 0.8061425061425062 random_state 4781
# accuracy score 0.8077395577395577 random_state 4782
# accuracy score 0.8042997542997543 random_state 4783
# accuracy score 0.7977886977886978 random_state 4784
# accuracy score 0.8025798525798525 random_state 4785
# accuracy score 0.8078624078624078 random_state 4786
# accuracy score 0.8025798525798525 random_state 4787
# accuracy score 0.8014742014742015 random_state 4788
# accuracy score 0.8063882063882064 random_state 4789
# accuracy score 0.8040540540540541 random_state 4790
# accuracy score 0.8056511056511056 random_state 4791
# accuracy score 0.793980343980344 random_state 4792
# accuracy score 0.8062653562653562 random_state 4793
# accuracy score 0.8055282555282556 random_state 4794
# accuracy score 0.8047911547911548 random_state 4795
# accuracy score 0.8001228501228501 random_state 4796
# accuracy score 0.8068796068796069 random_state 4797
# accuracy score 0.8012285012285012 random_state 4798
# accuracy score 0.8076167076167076 random_state 4799
# accuracy score 0.8040540540540541 random_state 4800
# accuracy score 0.8011056511056511 random_state 4801
# accuracy score 0.802948402948403 random_state 4802
# accuracy score 0.7985257985257985 random_state 4803
# accuracy score 0.800982800982801 random_state 4804
# accuracy score 0.8008599508599509 random_state 4805
# accuracy score 0.7974201474201474 random_state 4806
# accuracy score 0.7961916461916462 random_state 4807
# accuracy score 0.7997542997542998 random_state 4808
# accuracy score 0.8013513513513514 random_state 4809
# accuracy score 0.8078624078624078 random_state 4810
# accuracy score 0.8022113022113022 random_state 4811
# accuracy score 0.8063882063882064 random_state 4812
# accuracy score 0.8035626535626536 random_state 4813
# accuracy score 0.8044226044226044 random_state 4814
# accuracy score 0.8111793611793612 random_state 4815
# accuracy score 0.7997542997542998 random_state 4816
# accuracy score 0.8004914004914004 random_state 4817
# accuracy score 0.8044226044226044 random_state 4818
# accuracy score 0.7996314496314496 random_state 4819
# accuracy score 0.7960687960687961 random_state 4820
# accuracy score 0.7952088452088452 random_state 4821
# accuracy score 0.8056511056511056 random_state 4822
# accuracy score 0.803931203931204 random_state 4823
# accuracy score 0.803931203931204 random_state 4824
# accuracy score 0.8023341523341523 random_state 4825
# accuracy score 0.8031941031941032 random_state 4826
# accuracy score 0.7969287469287469 random_state 4827
# accuracy score 0.7921375921375922 random_state 4828
# accuracy score 0.8088452088452088 random_state 4829
# accuracy score 0.8055282555282556 random_state 4830
# accuracy score 0.8045454545454546 random_state 4831
# accuracy score 0.7954545454545454 random_state 4832
# accuracy score 0.7971744471744472 random_state 4833
# accuracy score 0.7993857493857494 random_state 4834
# accuracy score 0.8023341523341523 random_state 4835
# accuracy score 0.8020884520884521 random_state 4836
# accuracy score 0.8001228501228501 random_state 4837
# accuracy score 0.8044226044226044 random_state 4838
# accuracy score 0.801965601965602 random_state 4839
# accuracy score 0.8071253071253072 random_state 4840
# accuracy score 0.7950859950859951 random_state 4841
# accuracy score 0.7996314496314496 random_state 4842
# accuracy score 0.8033169533169533 random_state 4843
# accuracy score 0.8073710073710074 random_state 4844
# accuracy score 0.8087223587223588 random_state 4845
# accuracy score 0.802948402948403 random_state 4846
# accuracy score 0.8051597051597051 random_state 4847
# accuracy score 0.8027027027027027 random_state 4848
# accuracy score 0.8066339066339067 random_state 4849
# accuracy score 0.801965601965602 random_state 4850
# accuracy score 0.8038083538083538 random_state 4851
# accuracy score 0.7974201474201474 random_state 4852
# accuracy score 0.8007371007371007 random_state 4853
# accuracy score 0.8046683046683046 random_state 4854
# accuracy score 0.803071253071253 random_state 4855
# accuracy score 0.807002457002457 random_state 4856
# accuracy score 0.8040540540540541 random_state 4857
# accuracy score 0.806019656019656 random_state 4858
# accuracy score 0.8046683046683046 random_state 4859
# accuracy score 0.8024570024570025 random_state 4860
# accuracy score 0.807002457002457 random_state 4861
# accuracy score 0.8015970515970516 random_state 4862
# accuracy score 0.7996314496314496 random_state 4863
# accuracy score 0.8006142506142506 random_state 4864
# accuracy score 0.8012285012285012 random_state 4865
# accuracy score 0.8068796068796069 random_state 4866
# accuracy score 0.8057739557739557 random_state 4867
# accuracy score 0.8040540540540541 random_state 4868
# accuracy score 0.8065110565110565 random_state 4869
# accuracy score 0.8097051597051597 random_state 4870
# accuracy score 0.8042997542997543 random_state 4871
# accuracy score 0.8011056511056511 random_state 4872
# accuracy score 0.8007371007371007 random_state 4873
# accuracy score 0.7993857493857494 random_state 4874
# accuracy score 0.8015970515970516 random_state 4875
# accuracy score 0.7995085995085995 random_state 4876
# accuracy score 0.7998771498771499 random_state 4877
# accuracy score 0.8001228501228501 random_state 4878
# accuracy score 0.7969287469287469 random_state 4879
# accuracy score 0.8002457002457003 random_state 4880
# accuracy score 0.8057739557739557 random_state 4881
# accuracy score 0.8 random_state 4882
# accuracy score 0.8073710073710074 random_state 4883
# accuracy score 0.8067567567567567 random_state 4884
# accuracy score 0.8012285012285012 random_state 4885
# accuracy score 0.8050368550368551 random_state 4886
# accuracy score 0.8052825552825553 random_state 4887
# accuracy score 0.8055282555282556 random_state 4888
# accuracy score 0.7960687960687961 random_state 4889
# accuracy score 0.8034398034398035 random_state 4890
# accuracy score 0.7985257985257985 random_state 4891
# accuracy score 0.8006142506142506 random_state 4892
# accuracy score 0.8025798525798525 random_state 4893
# accuracy score 0.8012285012285012 random_state 4894
# accuracy score 0.7977886977886978 random_state 4895
# accuracy score 0.8035626535626536 random_state 4896
# accuracy score 0.802948402948403 random_state 4897
# accuracy score 0.8085995085995086 random_state 4898
# accuracy score 0.8038083538083538 random_state 4899
# accuracy score 0.8038083538083538 random_state 4900
# accuracy score 0.8006142506142506 random_state 4901
# accuracy score 0.8044226044226044 random_state 4902
# accuracy score 0.8012285012285012 random_state 4903
# accuracy score 0.7993857493857494 random_state 4904
# accuracy score 0.8003685503685504 random_state 4905
# accuracy score 0.7965601965601966 random_state 4906
# accuracy score 0.8034398034398035 random_state 4907
# accuracy score 0.8058968058968059 random_state 4908
# accuracy score 0.801965601965602 random_state 4909
# accuracy score 0.8017199017199017 random_state 4910
# accuracy score 0.8092137592137593 random_state 4911
# accuracy score 0.8033169533169533 random_state 4912
# accuracy score 0.7975429975429975 random_state 4913
# accuracy score 0.8022113022113022 random_state 4914
# accuracy score 0.8077395577395577 random_state 4915
# accuracy score 0.8072481572481572 random_state 4916
# accuracy score 0.7972972972972973 random_state 4917
# accuracy score 0.8067567567567567 random_state 4918
# accuracy score 0.8002457002457003 random_state 4919
# accuracy score 0.797051597051597 random_state 4920
# accuracy score 0.7996314496314496 random_state 4921
# accuracy score 0.801965601965602 random_state 4922
# accuracy score 0.8038083538083538 random_state 4923
# accuracy score 0.8006142506142506 random_state 4924
# accuracy score 0.8066339066339067 random_state 4925
# accuracy score 0.800982800982801 random_state 4926
# accuracy score 0.8018427518427519 random_state 4927
# accuracy score 0.7966830466830467 random_state 4928
# accuracy score 0.7995085995085995 random_state 4929
# accuracy score 0.8033169533169533 random_state 4930
# accuracy score 0.8057739557739557 random_state 4931
# accuracy score 0.8002457002457003 random_state 4932
# accuracy score 0.802948402948403 random_state 4933
# accuracy score 0.8072481572481572 random_state 4934
# accuracy score 0.8004914004914004 random_state 4935
# accuracy score 0.7987714987714988 random_state 4936
# accuracy score 0.8073710073710074 random_state 4937
# accuracy score 0.8055282555282556 random_state 4938
# accuracy score 0.8018427518427519 random_state 4939
# accuracy score 0.8001228501228501 random_state 4940
# accuracy score 0.8054054054054054 random_state 4941
# accuracy score 0.802948402948403 random_state 4942
# accuracy score 0.8004914004914004 random_state 4943
# accuracy score 0.8034398034398035 random_state 4944
# accuracy score 0.8077395577395577 random_state 4945
# accuracy score 0.8017199017199017 random_state 4946
# accuracy score 0.7950859950859951 random_state 4947
# accuracy score 0.8056511056511056 random_state 4948
# accuracy score 0.8034398034398035 random_state 4949
# accuracy score 0.7976658476658477 random_state 4950
# accuracy score 0.8025798525798525 random_state 4951
# accuracy score 0.8034398034398035 random_state 4952
# accuracy score 0.8065110565110565 random_state 4953
# accuracy score 0.7988943488943488 random_state 4954
# accuracy score 0.803071253071253 random_state 4955
# accuracy score 0.8036855036855037 random_state 4956
# accuracy score 0.8014742014742015 random_state 4957
# accuracy score 0.8035626535626536 random_state 4958
# accuracy score 0.7997542997542998 random_state 4959
# accuracy score 0.8 random_state 4960
# accuracy score 0.793980343980344 random_state 4961
# accuracy score 0.798034398034398 random_state 4962
# accuracy score 0.8015970515970516 random_state 4963
# accuracy score 0.807985257985258 random_state 4964
# accuracy score 0.8007371007371007 random_state 4965
# accuracy score 0.8018427518427519 random_state 4966
# accuracy score 0.7981572481572482 random_state 4967
# accuracy score 0.8008599508599509 random_state 4968
# accuracy score 0.7988943488943488 random_state 4969
# accuracy score 0.8049140049140049 random_state 4970
# accuracy score 0.8014742014742015 random_state 4971
# accuracy score 0.8034398034398035 random_state 4972
# accuracy score 0.803071253071253 random_state 4973
# accuracy score 0.8072481572481572 random_state 4974
# accuracy score 0.8094594594594594 random_state 4975
# accuracy score 0.8004914004914004 random_state 4976
# accuracy score 0.8 random_state 4977
# accuracy score 0.7984029484029485 random_state 4978
# accuracy score 0.8001228501228501 random_state 4979
# accuracy score 0.8057739557739557 random_state 4980
# accuracy score 0.8001228501228501 random_state 4981
# accuracy score 0.8084766584766585 random_state 4982
# accuracy score 0.8071253071253072 random_state 4983
# accuracy score 0.8015970515970516 random_state 4984
# accuracy score 0.8042997542997543 random_state 4985
# accuracy score 0.8074938574938575 random_state 4986
# accuracy score 0.8058968058968059 random_state 4987
# accuracy score 0.799017199017199 random_state 4988
# accuracy score 0.8025798525798525 random_state 4989
# accuracy score 0.8004914004914004 random_state 4990
# accuracy score 0.8013513513513514 random_state 4991
# accuracy score 0.8068796068796069 random_state 4992
# accuracy score 0.7993857493857494 random_state 4993
# accuracy score 0.8047911547911548 random_state 4994
# accuracy score 0.8092137592137593 random_state 4995
# accuracy score 0.7985257985257985 random_state 4996
# accuracy score 0.8003685503685504 random_state 4997
# accuracy score 0.797051597051597 random_state 4998
# accuracy score 0.7988943488943488 random_state 4999

# %%
print('accuracy score', maxAccu, 'random_state', i)
# Out:
# accuracy score 0.8174447174447175 random_state 10

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import plot_roc_curve

# %%
eg = LogisticRegression()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)
print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.7988943488943488
# [[5762  391]
#  [1246  741]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88      6153
#            1       0.65      0.37      0.48      1987
#
#     accuracy                           0.80      8140
#    macro avg       0.74      0.65      0.68      8140
# weighted avg       0.78      0.80      0.78      8140

# %%
from sklearn.model_selection import cross_val_score

acc = accuracy_score(y_test, y_pred)

for i in range (2,11):
    cvscore = cross_val_score(reg, x, y, cv = i)
    cvs = cvscore.mean()
    print("At CV:", i)
    print("Cross Validation Score is: ", cvs*100)
    print("Accuracy Score is : ", acc*100)
# Out:
# At CV: 2
# Cross Validation Score is:  76.62776412776412
# Accuracy Score is :  79.88943488943488
# At CV: 3
# Cross Validation Score is:  76.63698699224103
# Accuracy Score is :  79.88943488943488
# At CV: 4
# Cross Validation Score is:  76.60012285012284
# Accuracy Score is :  79.88943488943488
# At CV: 5
# Cross Validation Score is:  76.50184275184276
# Accuracy Score is :  79.88943488943488
# At CV: 6
# Cross Validation Score is:  77.1744375690183
# Accuracy Score is :  79.88943488943488
# At CV: 7
# Cross Validation Score is:  77.03620789054114
# Accuracy Score is :  79.88943488943488
# At CV: 8
# Cross Validation Score is:  76.6093366093366
# Accuracy Score is :  79.88943488943488
# At CV: 9
# Cross Validation Score is:  76.3144737373217
# Accuracy Score is :  79.88943488943488
# At CV: 10
# Cross Validation Score is:  76.6154791154791
# Accuracy Score is :  79.88943488943488

# %%
cvscore_selected = cross_val_score(reg, x, y, cv = 10).mean()
print("The CV Score is: ", cvscore_selected, "\nThe Accuracy Score is: ", acc)
# Out:
# The CV Score is:  0.766154791154791
# The Accuracy Score is:  0.7988943488943488

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.8122850122850123
# [[5499  654]
#  [ 874 1113]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.89      0.88      6153
#            1       0.63      0.56      0.59      1987
#
#     accuracy                           0.81      8140
#    macro avg       0.75      0.73      0.74      8140
# weighted avg       0.81      0.81      0.81      8140

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
y_pred = dt.predict(x_test)
print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.7793611793611793
# [[5269  884]
#  [ 912 1075]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85      6153
#            1       0.55      0.54      0.54      1987
#
#     accuracy                           0.78      8140
#    macro avg       0.70      0.70      0.70      8140
# weighted avg       0.78      0.78      0.78      8140

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.8213759213759214
# [[5591  562]
#  [ 892 1095]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88      6153
#            1       0.66      0.55      0.60      1987
#
#     accuracy                           0.82      8140
#    macro avg       0.76      0.73      0.74      8140
# weighted avg       0.81      0.82      0.82      8140

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
y_pred =svc.predict(x_test)
print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.8286240786240786
# [[5819  334]
#  [1061  926]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.89      6153
#            1       0.73      0.47      0.57      1987
#
#     accuracy                           0.83      8140
#    macro avg       0.79      0.71      0.73      8140
# weighted avg       0.82      0.83      0.81      8140

# %%
import xgboost as xgb
xgb = xgb.XGBClassifier()

xgb.fit(x_train, y_train)

y_pred = xgb.predict(x_test)

print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.8373464373464373
# [[5673  480]
#  [ 844 1143]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.90      6153
#            1       0.70      0.58      0.63      1987
#
#     accuracy                           0.84      8140
#    macro avg       0.79      0.75      0.76      8140
# weighted avg       0.83      0.84      0.83      8140

# %%
# auc roc plot
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import plot_roc_curve

# auc roc plot
import xgboost as xgb
clf = xgb.XGBClassifier()

clf.fit(x_train, y_train)

pred = clf.predict(x_test)
plot_roc_curve(clf, x_test, y_test)
plt.title("AUC ROC Plot")
plt.show()

# %%
# Saving the Model

import joblib
joblib.dump(clf, "Census_Income_Project.pkl")
# Out:
# ['Census_Income_Project.pkl']

# %%
import xgboost as xgb
xgb = xgb.XGBClassifier()

param_grid = {
        'min_child_weight': np.linspace(1, 10, 5, endpoint=True),
        'gamma': np.linspace(0.5, 5, 5, endpoint=True),
        'subsample': np.linspace(0.5, 1, 5, endpoint=True)
        }


grd = GridSearchCV(xgb, param_grid = param_grid)
grd.fit(x_train, y_train)

print('Best Param ==>', grd.best_params_)

xgbst = grd.best_estimator_      # reinstiating with best parameters

xgbst.fit(x_train, y_train)
y_pred = xgbst.predict(x_test)

xgb_conf_mat = confusion_matrix(y_test, y_pred)

print('\nconf_mat ==>', '\n', xgb_conf_mat)

print('\nAccuracy rf Normal ==>', '\n', accuracy_score(y_test, y_pred))
# Out:
# Best Param ==> {'gamma': 3.875, 'min_child_weight': 3.25, 'subsample': 1.0}
#
# conf_mat ==>
#  [[5689  464]
#  [ 811 1176]]
#
# Accuracy rf Normal ==>
#  0.8433660933660934
